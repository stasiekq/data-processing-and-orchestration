# %% [markdown]
# # E-commerce pipeline (wrapper)
#
# Single entry point for the assignment is `run_pipeline.py` in the repo root. This notebook only invokes it so you can run the same code interactively.

# %%
import subprocess
import sys
from pathlib import Path

repo = Path.cwd()
if not (repo / "run_pipeline.py").is_file():
    raise SystemExit("Run this notebook from the repository root.")

cmd = [sys.executable, str(repo / "run_pipeline.py")]
subprocess.run(cmd, check=True)
